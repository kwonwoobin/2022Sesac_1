# %%
import pandas as pd
scrapy_inactive_df = pd.read_csv(r'C:\Users\bin\Desktop\workspace\numble\scrapy_inactive_df.csv', index_col=0)

# %%
scrapy_inactive_df
# Out:
#                     기업명     휴폐업발생일자    휴폐업1년전날짜
# 0                "용진테크"  2022.05.18  2021.05.18
# 1                "신구건설"  2021.03.19  2020.03.19
# 2               "석정미디어"  2019.12.13  2018.12.13
# 3                "새한실업"  2021.05.31  2020.05.31
# 4            "석영엔터프라이즈"  2021.06.30  2020.06.30
# ...                 ...         ...         ...
# 6825          "게방식당팩토리"  2021.12.31  2020.12.31
# 6826         "우진푸드중부지점"  2021.11.26  2020.11.26
# 6827  "윤월드푸드코리아다크써클브로스"  2022.06.30  2021.06.30
# 6828             "기린테크"  2022.07.31  2021.07.31
# 6829             "우리로봇"  2022.05.11  2021.05.11
#
# [6830 rows x 3 columns]

# %%
# 그다음에 zip으로 하나의 리스트로 만들기
list1 = scrapy_inactive_df['기업명'].tolist()
list2 = scrapy_inactive_df['휴폐업발생일자'].tolist()
list3 = scrapy_inactive_df['휴폐업1년전날짜'].tolist()

list4 = list(zip(list1, list2, list3))

# %%
list4
# Out:
# [('"용진테크"', '2022.05.18', '2021.05.18'),
#  ('"신구건설"', '2021.03.19', '2020.03.19'),
#  ('"석정미디어"', '2019.12.13', '2018.12.13'),
#  ('"새한실업"', '2021.05.31', '2020.05.31'),
#  ('"석영엔터프라이즈"', '2021.06.30', '2020.06.30'),
#  ('"남경엔지니어링토건"', '2022.07.15', '2021.07.15'),
#  ('"유일철강"', '2021.03.05', '2020.03.05'),
#  ('"한일물산(주)서울직매장"', '2019.07.26', '2018.07.26'),
#  ('"그렉스전자"', '2022.04.30', '2021.04.30'),
#  ('"신한스틸"', '2019.06.28', '2018.06.28'),
#  ('"근유"', '2022.05.31', '2021.05.31'),
#  ('"하랑그룹"', '2020.09.04', '2019.09.04'),
#  ('"아이티스타"', '2019.06.01', '2018.06.01'),
#  ('"협진기계"', '2021.08.26', '2020.08.26'),
#  ('"아이세로미림화학"', '2021.12.30', '2020.12.30'),
#  ('"케이원목재"', '2022.05.20', '2021.05.20'),
#  ('"호연토건"', '2022.04.05', '2021.04.05'),
#  ('"경성섬유"', '2020.12.31', '2019.12.31'),
#  ('"금강특수"', '2021.09.03', '2020.09.03'),
#  ('"유진해운"', '2020.12.29', '2019.12.29'),
#  ('"유레카"', '2022.03.08', '2021.03.08'),
#  ('"로젠솔루션"', '2021.05.24', '2020.05.24'),
# ...

# %%
# urls = [f'https://search.naver.com/search.naver?where=news&query={a}&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds={c}&de={b}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210518to20220518&is_sug_officeid=0'for a,b,c in list4]

# %%
urls = [f'https://search.naver.com/search.naver?where=news&sm=tab_pge&query={a}&sort=1&photo=0&field=0&pd=3&ds={c}&de={b}&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start={d}1'for a,b,c in list4 for d in range(0,11)]

# %%
urls
# Out:
# ['https://search.naver.com/search.naver?where=news&sm=tab_pge&query="용진테크"&sort=1&photo=0&field=0&pd=3&ds=2021.05.18&de=2022.05.18&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=01',
#  'https://search.naver.com/search.naver?where=news&sm=tab_pge&query="용진테크"&sort=1&photo=0&field=0&pd=3&ds=2021.05.18&de=2022.05.18&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=11',
#  'https://search.naver.com/search.naver?where=news&sm=tab_pge&query="용진테크"&sort=1&photo=0&field=0&pd=3&ds=2021.05.18&de=2022.05.18&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=21',
# ...

# %%
urls
# Out:
# ['https://search.naver.com/search.naver?where=news&query="용진테크"&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2021.05.18&de=2022.05.18&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210518to20220518&is_sug_officeid=0',
#  'https://search.naver.com/search.naver?where=news&query="신구건설"&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2020.03.19&de=2021.03.19&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210518to20220518&is_sug_officeid=0',
#  'https://search.naver.com/search.naver?where=news&query="석정미디어"&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2018.12.13&de=2019.12.13&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210518to20220518&is_sug_officeid=0',
# ...

# %%
# 기업명에 쌍따옴표 붙여야함
# 10개 넘는 경우.. 페이지 넘기기 -> 맨 끝페이지 구해서 page에 파라
# 시간도 1초로 해도 되나

# %%
https://search.naver.com/search.naver?where=news&query=%22%EC%9C%A0%EC%9D%BC%EC%B2%A0%EA%B0%95%22&sm=tab_opt&sort=1&photo=0&field=0&pd=3&ds=2020.03.05&de=2021.03.05
&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Afrom20210518to20220518&is_sug_officeid=0

# %%
# 페이지2페이지로 넘김
https://search.naver.com/search.naver?where=news&sm=tab_pge&query=
%22%EC%9C%A0%EC%9D%BC%EC%B2%A0%EA%B0%95%22&sort=1&photo=0&field=0&pd=3&ds=
2020.03.05
&de=
2021.03.05
&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=11

# %%
#  3페이지
https://search.naver.com/search.naver?where=news&sm=tab_pge&query=
%22%EC%9C%A0%EC%9D%BC%EC%B2%A0%EA%B0%95%22&sort=1&photo=0&field=0&pd=3&ds=
2020.03.05
&de=
2021.03.05
&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=21

# %%
# 4페이지
https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%22%EC%9C%A0%EC%9D%BC%EC%B2%A0%EA%B0%95%22&sort=1&photo=0&field=0&pd=3&ds=2020.03.05&de=2021.03.05
&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start=31

# %%
# 다시 1페이지
https://search.naver.com/search.naver?where=news&sm=tab_pge&query=
%22%EC%9C%A0%EC%9D%BC%EC%B2%A0%EA%B0%95%22&sort=1&photo=0&field=0&pd=3&ds=
2020.03.05
&de=
2021.03.05
&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:dd,p:from20200305to20210305,a:all&start={d}1
